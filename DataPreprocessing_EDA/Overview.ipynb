# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import sys
# !{sys.executable} -m pip install --default-timeout=100 ydata-profiling

# %%
os.getcwd()
# Out:
# '/home/jovyan/shared/DataMining/project/DataPreprocessing_EDA'

# %%
TRAIN_DATA_FILEPATH = os.path.join(os.path.pardir, "Data", "PreprocessedData", "1_renamed_train_dataset.csv")
TEST_DATA_FILEPATH = os.path.join(os.path.pardir, "Data", "PreprocessedData", "1_renamed_test_dataset.csv")

# %%
train_data = pd.read_csv(TRAIN_DATA_FILEPATH)
test_data = pd.read_csv(TEST_DATA_FILEPATH)

# %%
set(train_data.columns) - {"smoking"} == set(test_data.columns)
# Out:
# True

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(train_data, 
                       title='Smoking Data Report',
                       minimal=True)  # Use minimal mode
profile.to_file("smoking_data_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
print(f"Train data shape: {train_data.shape}")
print(f"Test data shape: {test_data.shape}")
# Out:
# Train data shape: (38984, 23)
# Test data shape: (16708, 22)
