# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import sys
# !{sys.executable} -m pip install --default-timeout=100 ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 621.7/621.7 kB 12.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 54.8 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.9 MB/s eta 0:00:00
# ...
#   Created wheel for phik: filename=phik-0.12.5-cp311-cp311-linux_aarch64.whl size=676774 sha256=997663bbc197f29daf153df8611851257d8abbdb3a26180636c60fcea67365d5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/da/73/f4/144786da7b23857be10d978710283b151c40a3020daf69292c
# ...

# %%
os.getcwd()
# Out:
# '/home/jovyan/shared/DataMining/project/DataPreprocessing_EDA'

# %%
RAW_DATA_FILEPATH = os.path.join(os.path.pardir, "Data", "RawData", "train.csv")

# %%
raw_data = pd.read_csv(RAW_DATA_FILEPATH)

# %%
raw_data.shape
# Out:
# (159256, 24)

# %%
raw_data.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1               1       135  ...   40   75
# 1              0.7              2               2       146  ...   57  126
# 2              0.5              1               1       118  ...   45   93
# 3              1.2              1               1       131  ...   38  102
# 4              1.0              1               1       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(raw_data, 
                       title='Smoking Data Report',
                       minimal=True)  # Use minimal mode
profile.to_file("smoking_data_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
raw_data.isna().sum().sum()
# Out:
# 0
